# %%
import os
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date

# %%
# read in data

train_file = './train_users_2.csv.zip'
def zip_to_df(filepath):
    zfile = zipfile.ZipFile(filepath)
    for finfo in zfile.infolist():
        ifile = zfile.open(finfo)
        df = pd.read_csv(ifile)
    return df

df = zip_to_df(train_file)

# %%
df.head()

# %%
# Data clean up. 

df['gender'].replace('-unknown-', 'UNKNOWN', inplace=True)
df['gender'].replace(np.NaN, 'UNKNOWN', inplace=True)

# convert timestamp_first_active from string to datetime
df['timestamp_first_active'] = pd.to_datetime(df['timestamp_first_active'], format='%Y%m%d%H%M%S')

# set datetime values to datetime types
df['date_account_created'] = pd.to_datetime(df['date_account_created'])
df['date_first_booking'] = pd.to_datetime(df['date_first_booking'])


# the 'age' column has some extreme outliers and lots of missing values
# create a function for correcting values in age column, then apply
def check_age(age):
    if age in (np.nan, np.NaN):
        return np.NaN
    elif age >= 1000:
        # if age > 1000, I assume that the age value is actually birth year
        # subtract birth year from current year to calculate age
        return date.today().year - age
    else:
        return age
    
df['age'] = df['age'].apply(check_age)

# also add an age_group column

def age_group(age):
    if age in range(14):
        return '0-13'
    elif age in range(14,19):
        return '14-18'
    elif age in range(19, 26):
        return '19-25'
    elif age in range(26,36):
        return '26-35'
    elif age in range(36,51):
        return '36-50'
    elif age in range(51, 66):
        return '51-65'
    elif age > 65:
        return '66+'
    
    
df['age_group'] = df.age.apply(age_group)
df['age_group'].fillna('Unknown', inplace=True)
    
# calculate number of days to book 
df['days_to_book'] = df[df.country_destination != 'NDF'].date_first_booking - df[df.country_destination != 'NDF'].date_account_created
df['days_to_book'] = df.days_to_book.dt.days

# add device class column
def get_device_class(val):
    if str(val).lower().find('desktop') > 0:
        return 'Desktop'
    elif str(val).lower().find('phone') > 0:
        return 'Phone'
    elif val in ('iPad', 'Android Tablet'):
        return 'Tablet'
    else:
        return 'Unknown'

df['first_device_class'] = df['first_device_type'].apply(get_device_class)

# %%
# Plot of age data after removing extreme (> 1000) outliers
plt.figure(figsize=(8,4))
sns.distplot(df.age.loc[df.age.isnull() == False])
plt.title('User Age Distribution')
plt.show()

# %%
# Look at country destination by whether age is present or not
plt.figure(figsize=(18,6))

plt.subplot(1,3,1)

sns.countplot(data=df,
              x='country_destination',
              order=df['country_destination'].value_counts().index)
plt.title('All Data')
plt.xlabel('Country Destination')

plt.subplot(1,3,2)
sns.countplot(data=df.loc[df['age'].isnull() == False],
              x='country_destination',
              order=df['country_destination'].value_counts().index)
plt.title('Age Provided')
plt.xlabel('Country Destination')


plt.subplot(1,3,3)
sns.countplot(data=df.loc[df['age'].isnull() == True],
              x='country_destination',
              order=df['country_destination'].value_counts().index)
plt.title('No Age Provided')
plt.xlabel('Country Destination')

plt.show()
# the data indicates that having an age provided indicates a user is more likely to book a trip

# %%
# "Unknown" age appears to be associated with NDF (no destination). Does an "Unknown" value for gender
# also correlate with no destination chosen?
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='gender', order=['MALE', 'FEMALE', 'OTHER', 'UNKNOWN'])
plt.show()

plt.figure(figsize=(18,6))
plt.subplot(1,3,1)
sns.countplot(data=df,
              x='country_destination',
              order=df['country_destination'].value_counts().index)
plt.ylim(0,130000)
plt.title('All Data')
plt.xlabel('Country Destination')

plt.subplot(1,3,2)
sns.countplot(data=df.loc[df['gender'].isin(['MALE', 'FEMALE', 'OTHER'])],
              x='country_destination',
              order=df['country_destination'].value_counts().index)
plt.ylim(0,130000)
plt.title('Gender Provided')
plt.xlabel('Country Destination')

plt.subplot(1,3,3)
sns.countplot(data=df.loc[df['gender'] == 'UNKNOWN'],
              x='country_destination',
              order=df['country_destination'].value_counts().index)
plt.ylim(0,130000)
plt.title('Gender Not Provided')
plt.xlabel('Country Destination')

plt.show()
# Again we see that users who provide a gender appear to be more likely to book a trip
# though the correlation does not appear to be as strong as those users who provided/didn't provide an age

#adjust y-axes to same scale

# %%
pct_unknown = df.loc[df['gender'] == 'UNKNOWN'][['gender', 'country_destination']]['country_destination'].value_counts() / len(df.loc[df['gender'] == 'UNKNOWN'])
pct_mf = df.loc[df['gender'].isin(['MALE', 'FEMALE', 'OTHER'])][['gender', 'country_destination']]['country_destination'].value_counts() / len(df.loc[df['gender'].isin(['MALE', 'FEMALE', 'OTHER'])])
pct_all = df[['gender', 'country_destination']]['country_destination'].value_counts() / len(df)

plt.figure(figsize=(18,6))
plt.subplot(1,3,1)
pct_all.plot(kind='bar')
plt.xlabel('Country Destination')
plt.ylabel('Percent')
plt.title('All Data')

plt.subplot(1,3,2)
pct_mf.plot(kind='bar')
plt.xlabel('Country Destination')
plt.ylabel('Percent')
plt.title('Gender Provided')

plt.subplot(1,3,3)
pct_unknown.plot(kind='bar')
plt.xlabel('Country Destination')
plt.ylabel('Percent')
plt.title('Gender Unknown')


plt.show()

# %%
df6 = df.groupby('country_destination')['gender'].value_counts().unstack()

for ix in df6.index.values:
    df6.loc[ix] = df6.loc[ix] / len(df.loc[df.country_destination == ix])

df6 = df6[df['gender'].value_counts().index.tolist()]

_ = df6.plot(kind='bar', stacked=True, figsize=(10,5), legend=True)
_.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=2)
_.set_xlabel('County Destination')
_.set_ylabel('Percent')
plt.show()

# %%
# Can age and gender be used to predict the destination?

#print(ggplot(d, aes(signup_app, Freq, fill=destination_country)) + geom_bar(stat="identity"))
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='gender', hue='country_destination', 
             hue_order=df['country_destination'].value_counts().index)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=6)
plt.show()

plt.figure(figsize=(10,5))
sns.countplot(data=df, x='age_group', hue='country_destination', 
              hue_order=df['country_destination'].value_counts().index,
              order=['0-13', '14-18', '19-25', '26-35', '36-50', '51-65', '66+', 'Unknown'])
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=6)
plt.show()

# these charts are hard to read. I need to come back and reformat as stacked bar graphs, which sadly
# isn't as easy or straightforward in seaborn as it is in ggplot2

# %%
# get destination counts by gender
df2 = df.groupby('gender')['country_destination'].value_counts().unstack()
# create proportions
for ix in df2.index.values:
    df2.loc[ix] = df2.loc[ix] / len(df.loc[df.gender == ix])

df2 = df2[df['country_destination'].value_counts().index.tolist()]


_ = df2.plot(kind='bar', stacked=True, figsize=(10,5), legend=True)
_.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=6)
_.set_xlabel('Gender')
_.set_ylabel('Percent')
plt.show()

# %%
# get destination counts by age group
df3 = df.groupby('age_group')['country_destination'].value_counts().unstack()
# create proportions
for ix in df3.index.values:
    df3.loc[ix] = df3.loc[ix] / len(df.loc[df.age_group == ix])

df3 = df3[df['country_destination'].value_counts().index.tolist()]


_ = df3.plot(kind='bar', stacked=True, figsize=(10,5), legend=True)
_.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=6)
_.set_xlabel('Age Group')
_.set_ylabel('Percent')
plt.show()

# %%
# get destinations by signup method
df4 = df.groupby('signup_method')['country_destination'].value_counts().unstack()

# get proportions
for ix in df4.index.values:
    df4.loc[ix] = df4.loc[ix] / len(df.loc[df.signup_method == ix])

df4 = df4[df['country_destination'].value_counts().index.tolist()]

_ = df4.plot(kind='bar', stacked=True, figsize=(10,5), legend=True)
_.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=6, fancybox=True, shadow=True)
_.set_xlabel('Signup Method')
_.set_ylabel('Percent')
plt.show()

# %%
# get destinations by signup method
df5 = df.groupby('first_device_class')['country_destination'].value_counts().unstack()

# get proportions
for ix in df5.index.values:
    df5.loc[ix] = df5.loc[ix] / len(df.loc[df.first_device_class == ix])

df5 = df5[df['country_destination'].value_counts().index.tolist()]

_ = df5.plot(kind='bar', stacked=True, figsize=(10,5), legend=True)
_.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
          ncol=6, fancybox=True, shadow=True)
_.set_xlabel('Signup Device Type')
_.set_ylabel('Percent')
plt.show()

# %%
df.loc[df['gender'].isin(['MALE', 'FEMALE', 'OTHER'])]
# Out:
#                 id date_account_created timestamp_first_active  \
# 1       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 2       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 3       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 6       lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58
# 7       0d01nltbrs           2010-01-03    2010-01-03 19:19:05
# 8       a1vcnhxeij           2010-01-04    2010-01-04 00:42:11
# 10      yuuqmid2rp           2010-01-04    2010-01-04 19:42:51
# 11      om1ss59ys8           2010-01-05    2010-01-05 05:18:12
# 13      dy3rgx56cu           2010-01-05    2010-01-05 08:32:59
# 14      ju3h98ch3w           2010-01-07    2010-01-07 05:58:20
# 15      v4d5rl22px           2010-01-07    2010-01-07 20:45:55
# 19      gdka1q5ktd           2010-01-10    2010-01-10 01:08:17
# 21      qsibmuz9sx           2010-01-10    2010-01-10 22:09:41
# 24      7i49vnuav6           2010-01-11    2010-01-11 23:08:08
# 25      al8bcetz0g           2010-01-12    2010-01-12 13:14:44
# 27      hfrl5gle36           2010-01-12    2010-01-12 20:59:49
# 31      pggg2sj27u           2010-01-14    2010-01-14 06:07:57
# 33      qthj88nnc7           2010-01-14    2010-01-14 17:52:09
# 34      x9gnxoun57           2010-01-15    2010-01-15 05:50:53
# 36      7my0vrljxc           2010-01-15    2010-01-15 22:19:29
# 37      ul0b29nhr6           2010-01-15    2010-01-15 23:16:51
# 39      myunxar49t           2010-01-16    2010-01-16 15:49:42
# 40      jpne62dhz8           2010-01-16    2010-01-16 21:59:43
# 41      k15j7mbny0           2010-01-19    2010-01-19 01:36:16
# 42      2981o5kr7b           2010-01-21    2010-01-21 07:09:39
# 45      g1q6caq452           2010-01-23    2010-01-23 20:15:40
# 53      jtm5s5dhwx           2010-01-26    2010-01-26 00:22:45
# 56      bgel0c0qic           2010-01-27    2010-01-27 03:16:20
# 58      fp6ndcm5ak           2010-01-27    2010-01-27 23:20:16
# 61      b2iuaury7k           2010-01-29    2010-01-29 09:39:08
# ...            ...                  ...                    ...
# 213374  015fy89ycb           2014-06-30    2014-06-30 22:01:37
# 213375  tu6rd23hcj           2014-06-30    2014-06-30 22:02:03
# 213377  vtdr4zlbtb           2014-06-30    2014-06-30 22:03:05
# 213378  nhtc9mxlp7           2014-06-30    2014-06-30 22:03:26
# 213384  bzcqek3k51           2014-06-30    2014-06-30 22:11:15
# 213385  3yew808eqp           2014-06-30    2014-06-30 22:15:22
# 213387  sm6pwudrvv           2014-06-30    2014-06-30 22:20:34
# 213388  gedoe2zmrj           2014-06-30    2014-06-30 22:22:00
# 213390  c999p94qui           2014-06-30    2014-06-30 22:22:53
# 213393  2ntc2mstbz           2014-06-30    2014-06-30 22:30:10
# 213395  otum1j4w9u           2014-06-30    2014-06-30 22:31:50
# 213400  x17avasiuk           2014-06-30    2014-06-30 22:39:43
# 213402  jfcwjhkmtv           2014-06-30    2014-06-30 22:41:08
# 213403  f9bs0rczyv           2014-06-30    2014-06-30 22:41:50
# 213407  iu1abga5nx           2014-06-30    2014-06-30 22:46:35
# 213408  l8tltghomx           2014-06-30    2014-06-30 22:46:54
# 213409  git9gx54o9           2014-06-30    2014-06-30 22:48:02
# 213412  a1rvlsdijt           2014-06-30    2014-06-30 22:51:57
# 213416  pa8rnz3ne0           2014-06-30    2014-06-30 23:02:53
# 213417  zhf38bsj36           2014-06-30    2014-06-30 23:09:34
# 213423  3dx1jk6yk2           2014-06-30    2014-06-30 23:15:48
# 213424  hcfj07iowv           2014-06-30    2014-06-30 23:18:59
# 213425  l1f71f9vsj           2014-06-30    2014-06-30 23:21:19
# 213432  rg7ayg1tob           2014-06-30    2014-06-30 23:32:24
# 213439  msucfwmlzc           2014-06-30    2014-06-30 23:47:29
# 213440  04y8115avm           2014-06-30    2014-06-30 23:49:33
# 213441  omlc9iku7t           2014-06-30    2014-06-30 23:51:51
# 213443  0k26r3mir0           2014-06-30    2014-06-30 23:53:40
# 213445  qbxza0xojf           2014-06-30    2014-06-30 23:55:47
# 213446  zxodksqpep           2014-06-30    2014-06-30 23:56:36
#
#        date_first_booking  gender   age signup_method  signup_flow language  \
# 1                     NaT    MALE  38.0      facebook            0       en
# 2              2010-08-02  FEMALE  56.0         basic            3       en
# 3              2012-09-08  FEMALE  42.0      facebook            0       en
# 6              2010-01-05  FEMALE  46.0         basic            0       en
# 7              2010-01-13  FEMALE  47.0         basic            0       en
# 8              2010-07-29  FEMALE  50.0         basic            0       en
# 10             2010-01-06  FEMALE  36.0         basic            0       en
# 11                    NaT  FEMALE  47.0         basic            0       en
# 13                    NaT  FEMALE  37.0         basic            0       en
# 14                    NaT  FEMALE  36.0         basic            0       en
# 15             2010-01-08  FEMALE  33.0         basic            0       en
# 19             2010-01-10  FEMALE  29.0         basic            0       en
# 21             2010-01-11    MALE  30.0         basic            0       en
# 24                    NaT  FEMALE  40.0         basic            0       en
# 25             2010-01-15  FEMALE  26.0         basic            0       en
# 27             2010-01-22  FEMALE  32.0         basic            0       en
# 31                    NaT    MALE  31.0         basic            0       en
# 33                    NaT    MALE  29.0         basic            0       en
# 34                    NaT    MALE  59.0         basic            0       en
# 36             2010-01-15  FEMALE  31.0         basic            0       en
# 37                    NaT    MALE  30.0         basic            0       en
# 39                    NaT  FEMALE  35.0         basic            0       en
# 40                    NaT    MALE  26.0         basic            0       en
# 41             2010-01-21  FEMALE  30.0         basic            0       en
# 42                    NaT  FEMALE  29.0         basic            0       en
# 45             2010-01-27  FEMALE  44.0         basic            0       en
# 53                    NaT    MALE  28.0         basic            0       en
# 56                    NaT  FEMALE  53.0         basic            0       en
# 58             2010-01-27    MALE  52.0         basic            0       en
# 61                    NaT    MALE  39.0         basic            0       en
# ...                   ...     ...   ...           ...          ...      ...
# 213374                NaT  FEMALE  29.0         basic            0       en
# 213375                NaT  FEMALE  65.0      facebook            0       en
# 213377                NaT    MALE  24.0      facebook           25       en
# 213378         2014-07-04  FEMALE  38.0         basic            0       en
# 213384         2015-01-06    MALE  22.0         basic           25       en
# 213385         2014-11-22  FEMALE  39.0         basic           25       en
# 213387                NaT    MALE  27.0      facebook           25       en
# 213388         2015-03-01  FEMALE  30.0         basic            0       en
# 213390         2014-07-08  FEMALE  30.0         basic            0       en
# 213393                NaT  FEMALE  26.0      facebook            0       en
# 213395                NaT    MALE  33.0      facebook           25       en
# 213400         2014-08-04    MALE  53.0         basic           23       en
# 213402         2015-04-14    MALE  32.0      facebook            0       en
# 213403                NaT    MALE  27.0      facebook            0       en
# 213407         2014-06-30  FEMALE  21.0      facebook            0       en
# 213408         2014-07-08    MALE  69.0         basic           23       en
# 213409         2014-07-12  FEMALE  28.0      facebook            0       en
# 213412         2015-01-23  FEMALE  50.0         basic            0       en
# 213416                NaT    MALE   NaN         basic            8       en
# 213417                NaT  FEMALE  46.0         basic            0       en
# 213423                NaT  FEMALE  20.0      facebook           25       en
# 213424                NaT  FEMALE  32.0      facebook            0       en
# 213425                NaT  FEMALE  30.0      facebook            0       en
# 213432                NaT    MALE  31.0      facebook            0       en
# 213439         2015-03-16    MALE  43.0         basic            0       en
# 213440                NaT  FEMALE  24.0         basic           25       en
# 213441         2014-08-13  FEMALE  34.0         basic            0       en
# 213443         2014-07-13  FEMALE  36.0         basic            0       en
# 213445         2014-07-02  FEMALE  23.0         basic            0       en
# 213446                NaT    MALE  32.0         basic            0       en
#
#        affiliate_channel affiliate_provider first_affiliate_tracked  \
# 1                    seo             google               untracked
# 2                 direct             direct               untracked
# 3                 direct             direct               untracked
# 6                  other         craigslist               untracked
# 7                 direct             direct                     omg
# 8                  other         craigslist               untracked
# 10                 other         craigslist               untracked
# 11                 other         craigslist               untracked
# 13                 other         craigslist                  linked
# 14                 other         craigslist               untracked
# 15                direct             direct               untracked
# 19                direct             direct               untracked
# 21                direct             direct                  linked
# 24                   seo             google               untracked
# 25                 other         craigslist               untracked
# 27                 other         craigslist               untracked
# 31                direct             direct                     NaN
# 33                 other         craigslist                     NaN
# 34                direct             direct               untracked
# 36                direct             direct                  linked
# 37                 other         craigslist               untracked
# 39                 other         craigslist               untracked
# 40                 other         craigslist                  linked
# 41                direct             direct               untracked
# 42                direct             direct                     NaN
# 45                 other         craigslist               untracked
# 53                 other         craigslist                  linked
# 56                 other         craigslist                  linked
# 58                direct             direct               untracked
# 61                 other         craigslist               untracked
# ...                  ...                ...                     ...
# 213374         sem-brand             google                     omg
# 213375            direct             direct                  linked
# 213377            direct             direct               untracked
# 213378         sem-brand             google                     omg
# 213384            direct             direct               untracked
# 213385            direct             direct                  linked
# 213387            direct             direct               untracked
# 213388            direct             direct               untracked
# 213390            direct             direct                  linked
# 213393            direct             direct               untracked
# 213395            direct             direct               untracked
# 213400            direct             direct               untracked
# 213402         sem-brand             google                     omg
# 213403            direct             direct                  linked
# 213407         sem-brand             google                     omg
# 213408            direct             direct               untracked
# 213409            direct             direct               untracked
# 213412         sem-brand             google                     omg
# 213416            direct             direct               untracked
# 213417         sem-brand             google                     omg
# 213423            direct             direct               untracked
# 213424            direct             direct                  linked
# 213425            direct             direct                  linked
# 213432            direct             direct           tracked-other
# 213439            direct             direct               untracked
# 213440            direct             direct               untracked
# 213441            direct             direct                  linked
# 213443         sem-brand             google                  linked
# 213445         sem-brand             google                     omg
# 213446         sem-brand             google                     omg
#
#        signup_app first_device_type  first_browser country_destination  \
# 1             Web       Mac Desktop         Chrome                 NDF
# 2             Web   Windows Desktop             IE                  US
# 3             Web       Mac Desktop        Firefox               other
# 6             Web       Mac Desktop         Safari                  US
# 7             Web       Mac Desktop         Safari                  US
# 8             Web       Mac Desktop         Safari                  US
# 10            Web       Mac Desktop        Firefox                  US
# 11            Web            iPhone      -unknown-                 NDF
# 13            Web       Mac Desktop        Firefox                 NDF
# 14            Web            iPhone  Mobile Safari                 NDF
# 15            Web   Windows Desktop         Chrome                  CA
# 19            Web       Mac Desktop         Chrome                  FR
# 21            Web       Mac Desktop         Chrome                  US
# 24            Web       Mac Desktop        Firefox                 NDF
# 25            Web       Mac Desktop         Chrome                  FR
# 27            Web   Desktop (Other)         Chrome                  US
# 31            Web     Other/Unknown      -unknown-                 NDF
# 33            Web     Other/Unknown      -unknown-                 NDF
# 34            Web   Windows Desktop         Chrome                 NDF
# 36            Web       Mac Desktop         Safari                  US
# 37            Web   Windows Desktop         Chrome                 NDF
# 39            Web       Mac Desktop         Safari                 NDF
# 40            Web   Windows Desktop        Firefox                 NDF
# 41            Web       Mac Desktop         Chrome                  US
# 42            Web     Other/Unknown      -unknown-                 NDF
# 45            Web   Windows Desktop             IE                  US
# 53            Web   Windows Desktop         Chrome                 NDF
# 56            Web    Android Tablet         Chrome                 NDF
# 58            Web   Windows Desktop        Firefox                  US
# 61            Web            iPhone  Mobile Safari                 NDF
# ...           ...               ...            ...                 ...
# 213374        Web       Mac Desktop         Safari                 NDF
# 213375        Web       Mac Desktop         Chrome                 NDF
# 213377        iOS            iPhone      -unknown-                 NDF
# 213378        Web       Mac Desktop         Safari                  US
# 213384        iOS            iPhone  Mobile Safari                  US
# 213385        iOS            iPhone  Mobile Safari                  US
# 213387        iOS            iPhone      -unknown-                 NDF
# 213388        Web       Mac Desktop         Chrome                  IT
# 213390        Web       Mac Desktop         Chrome                  AU
# 213393        Web       Mac Desktop         Safari                 NDF
# 213395        iOS            iPhone      -unknown-                 NDF
# 213400    Android     Other/Unknown      -unknown-               other
# 213402        Web   Windows Desktop         Chrome                  US
# 213403        Web   Windows Desktop        Firefox                 NDF
# 213407        Web              iPad  Mobile Safari                  ES
# 213408    Android     Android Phone      -unknown-                  US
# 213409        Web   Windows Desktop        Firefox                  US
# 213412        Web   Windows Desktop         Chrome                  US
# 213416        Web            iPhone      -unknown-                 NDF
# 213417        Web   Windows Desktop         Chrome                 NDF
# 213423        iOS            iPhone      -unknown-                 NDF
# 213424        Web   Windows Desktop         Chrome                 NDF
# 213425        Web   Windows Desktop         Chrome                 NDF
# 213432        Web       Mac Desktop         Safari                 NDF
# 213439        Web   Windows Desktop        Firefox                  US
# 213440        iOS            iPhone  Mobile Safari                 NDF
# 213441        Web       Mac Desktop         Chrome                  ES
# 213443        Web       Mac Desktop         Safari                  US
# 213445        Web   Windows Desktop             IE                  US
# 213446        Web       Mac Desktop         Safari                 NDF
#
#        age_group  days_to_book first_device_class
# 1          36-50           NaN            Desktop
# 2          51-65         -57.0            Desktop
# 3          36-50         278.0            Desktop
# 6          36-50           3.0            Desktop
# 7          36-50          10.0            Desktop
# 8          36-50         206.0            Desktop
# 10         36-50           2.0            Desktop
# 11         36-50           NaN              Phone
# 13         36-50           NaN            Desktop
# 14         36-50           NaN              Phone
# 15         26-35           1.0            Desktop
# 19         26-35           0.0            Desktop
# 21         26-35           1.0            Desktop
# 24         36-50           NaN            Desktop
# 25         26-35           3.0            Desktop
# 27         26-35          10.0            Unknown
# 31         26-35           NaN            Unknown
# 33         26-35           NaN            Unknown
# 34         51-65           NaN            Desktop
# 36         26-35           0.0            Desktop
# 37         26-35           NaN            Desktop
# 39         26-35           NaN            Desktop
# 40         26-35           NaN            Desktop
# 41         26-35           2.0            Desktop
# 42         26-35           NaN            Unknown
# 45         36-50           4.0            Desktop
# 53         26-35           NaN            Desktop
# 56         51-65           NaN             Tablet
# 58         51-65           0.0            Desktop
# 61         36-50           NaN              Phone
# ...          ...           ...                ...
# 213374     26-35           NaN            Desktop
# 213375     51-65           NaN            Desktop
# 213377     19-25           NaN              Phone
# 213378     36-50           4.0            Desktop
# 213384     19-25         190.0              Phone
# 213385     36-50         145.0              Phone
# 213387     26-35           NaN              Phone
# 213388     26-35         244.0            Desktop
# 213390     26-35           8.0            Desktop
# 213393     26-35           NaN            Desktop
# 213395     26-35           NaN              Phone
# 213400     51-65          35.0            Unknown
# 213402     26-35         288.0            Desktop
# 213403     26-35           NaN            Desktop
# 213407     19-25           0.0             Tablet
# 213408       66+           8.0              Phone
# 213409     26-35          12.0            Desktop
# 213412     36-50         207.0            Desktop
# 213416   Unknown           NaN              Phone
# 213417     36-50           NaN            Desktop
# 213423     19-25           NaN              Phone
# 213424     26-35           NaN            Desktop
# 213425     26-35           NaN            Desktop
# 213432     26-35           NaN            Desktop
# 213439     36-50         259.0            Desktop
# 213440     19-25           NaN              Phone
# 213441     26-35          44.0            Desktop
# 213443     36-50          13.0            Desktop
# 213445     19-25           2.0            Desktop
# 213446     26-35           NaN            Desktop
#
# [117763 rows x 19 columns]

# %%
# Upsample 
#
